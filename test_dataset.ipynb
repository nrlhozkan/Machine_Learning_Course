# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('athlete_events.csv')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# Find the athletes from Turkey
turkey_athletes = df[df['NOC'] == 'TUR']
turkey_athletes_medal = turkey_athletes[turkey_athletes['Medal'] == 'Gold']

# %%
three_data_columns = turkey_athletes_medal[['Name', 'Year', 'Sport']]
three_data_columns
# Out:
#                              Name  Year          Sport
# 2846                   Nasuh Akar  1948      Wrestling
# 2926                    Taha Akgl  2016      Wrestling
# 10508               Mahmut Atalay  1968      Wrestling
# 10618          Celal Atik (Doan-)  1948      Wrestling
# 10675                    smet Atl  1960      Wrestling
# 11433                   Ahmet Ayk  1968      Wrestling
# 11505                  Kazm Ayvaz  1964      Wrestling
# 16642               Mithat Bayrak  1956      Wrestling
# 16643               Mithat Bayrak  1960      Wrestling
# 21751                 Ahmet Bilek  1960      Wrestling
# 21765              Gazanfer Bilge  1948      Wrestling
# 33626         Asl akr (-Alptekin)  2012      Athletics
# 48143             Mustafa Dastanl  1956      Wrestling
# 48144             Mustafa Dastanl  1960      Wrestling
# 53574                Mahmut Demir  1996      Wrestling
# 56787                    Yaar Dou  1948      Wrestling
# ...

# %%
# Out:
#             ID  Year          Sport
# 2846      1579  1948      Wrestling
# 2926      1634  2016      Wrestling
# 10508     5741  1968      Wrestling
# 10618     5806  1948      Wrestling
# 10675     5834  1960      Wrestling
# 11433     6244  1968      Wrestling
# 11505     6284  1964      Wrestling
# 16642     8930  1956      Wrestling
# 16643     8930  1960      Wrestling
# 21751    11489  1960      Wrestling
# 21765    11497  1948      Wrestling
# 33626    17338  2012      Athletics
# 48143    24819  1956      Wrestling
# 48144    24819  1960      Wrestling
# 53574    27485  1996      Wrestling
# 56787    29098  1948      Wrestling
# 64488    33012  1936      Wrestling
# 77694    39434  1952      Wrestling
# 86570    43903  1960      Wrestling
# 113162   57333  1956      Wrestling
# 119873   60688  1948      Wrestling
# 120121   60796  1960      Wrestling
# 166749   83764  1996  Weightlifting
# 166750   83764  2000  Weightlifting
# 166751   83764  2004  Weightlifting
# ...

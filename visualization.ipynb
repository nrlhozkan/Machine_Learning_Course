# %%
# %pip - V
# %pip install seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "-"
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('athlete_events.csv')

# %%
data.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
plt.scatter(data['Height'], data['Weight'])
plt.title('Height vs Weight of Athletes')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')   
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.scatterplot(x='Height', y='Weight', data=data)
plt.title('Height vs Weight of Athletes')
plt.xlabel('Height of Athletes (cm)')
plt.ylabel('Weight of Athletes (kg)')
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.scatterplot(x='Height', y='Weight', hue='Sex', data=data)
plt.title('Height vs Weight of Athletes')
plt.xlabel('Height of Athletes (cm)')
plt.ylabel('Weight of Athletes (kg)')
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.scatterplot(x='Height', y='Weight', hue='Sex', style='Medal', data=data)
plt.title('Height vs Weight of Athletes')
plt.xlabel('Height of Athletes (cm)')
plt.ylabel('Weight of Athletes (kg)')
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.scatterplot(x='Height', y='Weight', hue='Sex', style='Medal', size='Age', data=data)
plt.title('Height vs Weight of Athletes')
plt.xlabel('Height of Athletes (cm)')
plt.ylabel('Weight of Athletes (kg)')
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.lineplot(x='Height', y='Weight', hue = 'Sex', data=data)
plt.title('Height vs Weight of Athletes')
plt.xlabel('Height of Athletes (cm)')
plt.ylabel('Weight of Athletes (kg)')
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.displot(x='Height', data = data)
plt.ylabel("Frequency")
plt.title("Athletes Height Distribution")
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.displot(x='Height', hue='Sex', data=data, kind="kde")
plt.ylabel("Frequency")
plt.title("Athletes Height Distribution")
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.barplot(x='Medal', y='Height', hue='Sex', data=data)
plt.title('Medals by Height of Athletes')
plt.xlabel('Height of Athletes (cm)')   
plt.ylabel('Medal Type')
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.catplot(x='Medal', y='Height', hue='Sex', col = 'Season', data=data)
plt.title('Medals by Height of Athletes')
plt.xlabel('Height of Athletes (cm)')   
plt.ylabel('Medal Type')
plt.show()

# %%
data_1988 = data[data['Year'] == 1988]
data_1988_england = data_1988[data_1988['NOC'] == 'GBR']
data_1988_england = data_1988_england[data_1988_england['Sport'] == 'Ski Jumping']
data_1988_england
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 61459  31480  Michael Thomas "Eddie" Edwards   M  24.0   173.0    74.0
# 61460  31480  Michael Thomas "Eddie" Edwards   M  24.0   173.0    74.0
#
#                 Team  NOC        Games  Year  Season     City        Sport  \
# 61459  Great Britain  GBR  1988 Winter  1988  Winter  Calgary  Ski Jumping
# 61460  Great Britain  GBR  1988 Winter  1988  Winter  Calgary  Ski Jumping
#
#                                            Event Medal
# 61459  Ski Jumping Men's Normal Hill, Individual   NaN
# 61460   Ski Jumping Men's Large Hill, Individual   NaN

# %%
# Find Michael Thomas "Eddie" Edwards in data
data_eddie = data[(data['Name'] == "Michael Thomas \"Eddie\" Edwards")]
data_eddie
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 61459  31480  Michael Thomas "Eddie" Edwards   M  24.0   173.0    74.0
# 61460  31480  Michael Thomas "Eddie" Edwards   M  24.0   173.0    74.0
#
#                 Team  NOC        Games  Year  Season     City        Sport  \
# 61459  Great Britain  GBR  1988 Winter  1988  Winter  Calgary  Ski Jumping
# 61460  Great Britain  GBR  1988 Winter  1988  Winter  Calgary  Ski Jumping
#
#                                            Event Medal
# 61459  Ski Jumping Men's Normal Hill, Individual   NaN
# 61460   Ski Jumping Men's Large Hill, Individual   NaN

# %%
data_1988 = data[data['Year'] == 1988]
data_1988_finland = data_1988[data_1988['NOC'] == 'FIN']
data_1988_finland = data_1988_finland[data_1988_finland['Sport'] == 'Ski Jumping']
data_1988_finland
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 130336   65606         Risto Juhani Laakkonen   M  20.0   189.0    62.0
# 171593   86232              Ari-Pekka Nikkola   M  18.0   173.0    59.0
# 171594   86232              Ari-Pekka Nikkola   M  18.0   173.0    59.0
# 171595   86232              Ari-Pekka Nikkola   M  18.0   173.0    59.0
# 174254   87525  Matti Ensio Nyknen (-Paanala)   M  24.0   177.0    54.0
# 174255   87525  Matti Ensio Nyknen (-Paanala)   M  24.0   177.0    54.0
# 174256   87525  Matti Ensio Nyknen (-Paanala)   M  24.0   177.0    54.0
# 194134   97452          Jari Markus Puikkonen   M  28.0   180.0    68.0
# 194135   97452          Jari Markus Puikkonen   M  28.0   180.0    68.0
# 194136   97452          Jari Markus Puikkonen   M  28.0   180.0    68.0
# 232451  116607            Pekka Antero Suorsa   M  20.0   175.0    56.5
# 265836  133014          Tuomo Sakari Ylipulli   M  22.0   179.0    65.5
#
# ...
